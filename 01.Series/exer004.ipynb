# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
g = np.random.default_rng(0)
s = Series(g.normal(0, 100, 100_000))
s.describe()
# Out:
# count    100000.000000
# mean         -0.090825
# std         100.013350
# min        -449.411704
# 25%         -67.292120
# 50%          -0.414699
# 75%          67.636542
# max         473.195769
# dtype: float64

# %%
s.loc[s == s.min()] = 5 * s.max()
s.describe()
# Out:
# count    100000.000000
# mean         -0.062671
# std         100.282770
# min        -402.315865
# 25%         -67.288054
# 50%          -0.409289
# 75%          67.640758
# max        2365.978844
# dtype: float64

# %%
# within one standard deviation
s[(s > s.mean() - s.std()) &
  (s < s.mean() + s.std())].count() / s.count()
# Out:
# 0.68523

# %%
# within two standard deviations
s[(s > s.mean() - 2*s.std()) &
  (s < s.mean() + 2*s.std())].count() / s.count()
# Out:
# 0.95511

# %%
# within three standard deviations
s[(s > s.mean() - 3*s.std()) &
  (s < s.mean() + 3*s.std())].count() / s.count()
# Out:
# 0.99718

# %%
(s[s < s.mean()].mean() + s[s > s.mean()].mean() ) / 2, s.mean()
# Out:
# (0.17198897732535556, -0.06267117182870444)

# %%
s[(s < s.mean() - 3 * s.std()) |
  (s > s.mean() + 3 * s.std())].mean()
# Out:
# -2.02951883694736
